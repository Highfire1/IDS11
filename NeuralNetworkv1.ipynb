# %% [markdown]
# <a href="https://colab.research.google.com/github/Highfire1/IDS11/blob/main/NeuralNetworkv1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Welcome to a walkthrough of Neural Network v1.0
#
# Thanks to google, you can run this code online, on this website, for free!
#
# Two options:
#
# - click the play button on every cell and watch the code execute in live time
# - click Runtime -> Run All
#
# Thanks for reading!

# %%
# used for importing csv (excel) file
import pandas as pd
import numpy as np

# Make numpy values easier to read, apparently
np.set_printoptions(precision=3, suppress=True)

# machine learning library that abstracts everything away
import tensorflow as tf
# sub library (keras) of sorts with more specialized functions
from tensorflow.keras import layers

# %%
# get fake data from github and read it as a .csv file
file_dir = r'https://raw.githubusercontent.com/Highfire1/IDS11/main/fake_data.csv'
fake_data_train = pd.read_csv(file_dir, header = 0)

# %%
# print it out, just to make sure we have the right file
fake_data_train.head()
# Out:
#    playtime  joincount  game_interactions  tnt_ratio  grieferbool
# 0        45         40                447          5            0
# 1       147          3                953         12            0
# 2       204         43                 85          8            0
# 3       551          7                255         21            0
# 4        26         35                563         11            0

# %%
# seperate the csv file into two datasets 
# player_info stores playtime, joincount, game_interactions and tnt_ratio
# grieferbool stores grieferbool
# keep in mind that there are 10 000 rows 
player_info = fake_data_train.copy()
grieferbool = player_info.pop('grieferbool')

# convert into a numpy array which is mandatory for the tensorflow library as apparently it computes faster
# (this is above my paygrade I don't have a better explanation)
player_info = np.array(player_info)
grieferbool = np.array(grieferbool)

# %%
player_info # should match up to what you saw in block # 3

# think of this as code being run in the interpreter so it doesn't need print()
# Out:
# array([[ 45,  40, 447,   5],
#        [147,   3, 953,  12],
#        [204,  43,  85,   8],
#        ...,
#        [747,  13, 461,   6],
#        [ 48,   8, 357,  17],
#        [112,  19, 647,   1]])

# %%
grieferbool # should also match to the latter half of block # 3
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
# THE KEYSTONE PART

# This is where the neural network is defined. 

# this sets up the most basic of all neural networks - a SEQUENTIAL NEURAL NETWORK has one layer of input and one layer of output. Very simple and the easiest to set up.
player_model = tf.keras.Sequential([
                                    
  layers.Dense(64), # I believe (though the resources I'm looking through all assume prior knowledge of machine learning concepts which I do not possess) that this is the hidden layer.
                    # In other words, this is the layer in which all the math is done.

  layers.Dense(1)   # it is all then compressed into one node
])

# this lets the algorithm know what to improve on
# The loss looks at the output from the neural network then at the true value, then flips some switches(changes weights) in the neural network to make it approach the true value
# Because of this, if you let the neural network train for too long, it can learn all the values in a single dataset and become less useful in real world usage (known as overfitting)

# Trying to figure out what on earth Adam means also runs into the resources assuming prior knowledge problem but it appears that Adam is a name for a type of algorithm that  
# applies the above weights to the program using a method called stochastic gradient descent. Apparently, Adam can do it better and faster than a traditional algorithm.
player_model.compile(loss = tf.losses.MeanSquaredError(),
                      optimizer = tf.optimizers.Adam())

# %%
# TRAIN THE NEURAL NETWORK

# as previously mentioned, a neural network needs to train through a dataset with many records in order to work effectively
# Of course, it takes the player data, but theres also a setting for epochs
# Basically, an epoch defines how long the neural network will train for
# Every epoch, each record in the training set affects the neural network once. If you set this too high, you will overfit your model and it will become less effective.
# For now, ten is a reasonable number and works well
player_model.fit(player_info, grieferbool, epochs=10)
# Out:
# Epoch 1/10
# 313/313 [==============================] - 1s 1ms/step - loss: 45.3417
# Epoch 2/10
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1538
# Epoch 3/10
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1448
# Epoch 4/10
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1399
# Epoch 5/10
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1279
# Epoch 6/10
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1162
# Epoch 7/10
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1258
# Epoch 8/10
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1366
# Epoch 9/10
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1960
# Epoch 10/10
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1567

# %%
# Now what?
# Using the neural network:

# download a second (smaller) dataset from Github
# exact same stuff as in block # 2
file_dir = r'https://raw.githubusercontent.com/Highfire1/IDS11/main/fake_data_small.csv'
fake_data_small = pd.read_csv(file_dir, header = 0)

grieferboollist = fake_data_small.pop('grieferbool')
fake_data_small  = np.array(fake_data_small)

# %%
# KEYSTONE BLOCK # 2

# run the trained neural network on the new data
predictions = player_model.predict(fake_data_small)

# %%
# and print output
# of course, instead of printing in a for loop, you can call a function or write it back to another file, but for conveniences sake:

good = 0
bad = 0

for num in range(len(predictions)):
  print(str(num) + ': predict:' + str(predictions[num]) + ' real:[' + str(grieferboollist[num]), end = '] ')

  # convert all potential outputs to a bool
  if float(predictions[num]) > 0.5:
    predictbool = 1
  else:
    predictbool = 0

  if predictbool == grieferboollist[num]:
    print("GOOD")
    good += 1
  else:
    print("BAD")
    bad += 1
# Out:
# 0: predict:[0.468] real:[1] BAD
# 1: predict:[-0.067] real:[0] GOOD
# 2: predict:[0.517] real:[1] GOOD
# 3: predict:[0.692] real:[1] GOOD
# 4: predict:[0.128] real:[0] GOOD
# 5: predict:[0.751] real:[1] GOOD
# 6: predict:[0.614] real:[1] GOOD
# 7: predict:[0.533] real:[0] BAD
# 8: predict:[0.261] real:[0] GOOD
# 9: predict:[0.452] real:[1] BAD
# 10: predict:[0.625] real:[1] GOOD
# 11: predict:[0.059] real:[0] GOOD
# 12: predict:[0.856] real:[1] GOOD
# 13: predict:[0.144] real:[0] GOOD
# 14: predict:[-0.213] real:[0] GOOD
# 15: predict:[-0.239] real:[0] GOOD
# 16: predict:[0.445] real:[0] GOOD
# 17: predict:[0.016] real:[0] GOOD
# 18: predict:[-0.034] real:[0] GOOD
# 19: predict:[0.784] real:[1] GOOD
# 20: predict:[0.666] real:[1] GOOD
# 21: predict:[-0.302] real:[0] GOOD
# 22: predict:[0.736] real:[1] GOOD
# 23: predict:[0.712] real:[1] GOOD
# 24: predict:[0.836] real:[1] GOOD
# 25: predict:[0.654] real:[0] BAD
# 26: predict:[0.717] real:[1] GOOD
# 27: predict:[-0.31] real:[0] GOOD
# 28: predict:[0.028] real:[0] GOOD
# 29: predict:[0.257] real:[0] GOOD
# 30: predict:[0.62] real:[1] GOOD
# 31: predict:[0.499] real:[0] GOOD
# 32: predict:[0.85] real:[1] GOOD
# 33: predict:[0.681] real:[1] GOOD
# 34: predict:[0.22] real:[0] GOOD
# 35: predict:[0.734] real:[1] GOOD
# 36: predict:[0.059] real:[0] GOOD
# 37: predict:[0.685] real:[1] GOOD
# 38: predict:[0.82] real:[1] GOOD
# 39: predict:[0.015] real:[0] GOOD
# 40: predict:[1.047] real:[1] GOOD
# 41: predict:[0.678] real:[1] GOOD
# 42: predict:[0.731] real:[1] GOOD
# 43: predict:[1.021] real:[1] GOOD
# 44: predict:[0.991] real:[1] GOOD
# 45: predict:[0.025] real:[0] GOOD
# 46: predict:[-0.226] real:[0] GOOD
# 47: predict:[1.011] real:[1] GOOD
# 48: predict:[-0.455] real:[0] GOOD
# 49: predict:[0.569] real:[1] GOOD
# 50: predict:[0.553] real:[1] GOOD
# 51: predict:[-0.14] real:[0] GOOD
# 52: predict:[0.971] real:[1] GOOD
# 53: predict:[0.506] real:[1] GOOD
# 54: predict:[-0.306] real:[0] GOOD
# 55: predict:[-0.523] real:[0] GOOD
# 56: predict:[0.996] real:[1] GOOD
# 57: predict:[0.574] real:[1] GOOD
# 58: predict:[-0.128] real:[0] GOOD
# 59: predict:[0.276] real:[0] GOOD
# 60: predict:[0.074] real:[0] GOOD
# 61: predict:[0.519] real:[1] GOOD
# 62: predict:[-0.309] real:[0] GOOD
# 63: predict:[-0.738] real:[0] GOOD
# 64: predict:[0.842] real:[1] GOOD
# 65: predict:[-0.236] real:[0] GOOD
# 66: predict:[0.875] real:[1] GOOD
# 67: predict:[0.192] real:[0] GOOD
# 68: predict:[0.743] real:[1] GOOD
# 69: predict:[-0.555] real:[0] GOOD
# 70: predict:[-0.542] real:[0] GOOD
# 71: predict:[0.962] real:[1] GOOD
# 72: predict:[0.504] real:[0] BAD
# 73: predict:[-0.926] real:[0] GOOD
# 74: predict:[0.54] real:[0] BAD
# 75: predict:[-0.654] real:[0] GOOD
# 76: predict:[0.77] real:[1] GOOD
# 77: predict:[-0.169] real:[0] GOOD
# 78: predict:[-0.093] real:[0] GOOD
# 79: predict:[0.087] real:[0] GOOD
# 80: predict:[0.927] real:[1] GOOD
# 81: predict:[0.297] real:[0] GOOD
# 82: predict:[0.206] real:[0] GOOD
# 83: predict:[0.714] real:[0] BAD
# 84: predict:[-0.176] real:[0] GOOD
# 85: predict:[0.176] real:[0] GOOD
# 86: predict:[0.287] real:[0] GOOD
# 87: predict:[0.058] real:[0] GOOD
# 88: predict:[0.358] real:[0] GOOD
# 89: predict:[-0.073] real:[0] GOOD
# 90: predict:[0.654] real:[1] GOOD
# 91: predict:[0.611] real:[1] GOOD
# 92: predict:[0.165] real:[0] GOOD
# 93: predict:[0.869] real:[0] BAD
# 94: predict:[0.132] real:[0] GOOD
# 95: predict:[0.728] real:[1] GOOD
# 96: predict:[0.747] real:[1] GOOD
# 97: predict:[-0.386] real:[0] GOOD
# 98: predict:[0.493] real:[1] BAD
# 99: predict:[-0.017] real:[0] GOOD
# 100: predict:[0.19] real:[0] GOOD
# 101: predict:[0.941] real:[1] GOOD
# 102: predict:[0.88] real:[1] GOOD
# 103: predict:[0.74] real:[1] GOOD
# 104: predict:[0.642] real:[1] GOOD
# 105: predict:[0.55] real:[1] GOOD
# 106: predict:[-0.331] real:[0] GOOD
# 107: predict:[0.061] real:[0] GOOD
# 108: predict:[-0.779] real:[0] GOOD
# 109: predict:[0.073] real:[0] GOOD
# 110: predict:[0.899] real:[1] GOOD
# 111: predict:[0.438] real:[0] GOOD
# 112: predict:[0.829] real:[1] GOOD
# 113: predict:[0.742] real:[1] GOOD
# 114: predict:[0.565] real:[0] BAD
# 115: predict:[0.655] real:[1] GOOD
# 116: predict:[0.738] real:[1] GOOD
# 117: predict:[0.772] real:[1] GOOD
# 118: predict:[0.909] real:[1] GOOD
# 119: predict:[0.58] real:[1] GOOD
# 120: predict:[1.087] real:[1] GOOD
# 121: predict:[0.665] real:[1] GOOD
# 122: predict:[0.257] real:[0] GOOD
# 123: predict:[-0.34] real:[0] GOOD
# 124: predict:[-0.329] real:[0] GOOD
# 125: predict:[0.065] real:[0] GOOD
# 126: predict:[-0.363] real:[0] GOOD
# 127: predict:[0.771] real:[1] GOOD
# 128: predict:[0.238] real:[0] GOOD
# 129: predict:[0.213] real:[0] GOOD
# 130: predict:[0.626] real:[1] GOOD
# 131: predict:[0.862] real:[1] GOOD
# 132: predict:[0.889] real:[1] GOOD
# 133: predict:[-0.282] real:[0] GOOD
# 134: predict:[-0.011] real:[0] GOOD
# 135: predict:[0.54] real:[1] GOOD
# 136: predict:[0.11] real:[0] GOOD
# 137: predict:[0.16] real:[0] GOOD
# 138: predict:[0.305] real:[0] GOOD
# 139: predict:[0.766] real:[1] GOOD
# 140: predict:[0.293] real:[0] GOOD
# 141: predict:[0.998] real:[1] GOOD
# 142: predict:[0.716] real:[1] GOOD
# 143: predict:[-0.187] real:[0] GOOD
# 144: predict:[0.523] real:[1] GOOD
# 145: predict:[0.681] real:[1] GOOD
# 146: predict:[0.793] real:[1] GOOD
# 147: predict:[-0.179] real:[0] GOOD
# 148: predict:[0.329] real:[0] GOOD
# 149: predict:[0.245] real:[0] GOOD
# 150: predict:[-0.437] real:[0] GOOD
# 151: predict:[-0.163] real:[0] GOOD
# 152: predict:[0.864] real:[1] GOOD
# 153: predict:[-0.646] real:[0] GOOD
# 154: predict:[-0.418] real:[0] GOOD
# 155: predict:[0.949] real:[1] GOOD
# 156: predict:[-0.111] real:[0] GOOD
# 157: predict:[-0.155] real:[0] GOOD
# 158: predict:[-0.178] real:[0] GOOD
# 159: predict:[-0.072] real:[0] GOOD
# 160: predict:[0.487] real:[1] BAD
# 161: predict:[0.014] real:[0] GOOD
# 162: predict:[0.461] real:[0] GOOD
# 163: predict:[0.966] real:[1] GOOD
# 164: predict:[0.774] real:[1] GOOD
# 165: predict:[-0.279] real:[0] GOOD
# 166: predict:[-0.338] real:[0] GOOD
# 167: predict:[0.664] real:[1] GOOD
# 168: predict:[0.731] real:[1] GOOD
# 169: predict:[-0.018] real:[0] GOOD
# 170: predict:[0.701] real:[1] GOOD
# 171: predict:[0.591] real:[1] GOOD
# 172: predict:[0.716] real:[1] GOOD
# 173: predict:[-0.4] real:[0] GOOD
# 174: predict:[0.761] real:[1] GOOD
# 175: predict:[-0.085] real:[0] GOOD
# 176: predict:[0.506] real:[1] GOOD
# 177: predict:[0.118] real:[0] GOOD
# 178: predict:[0.224] real:[0] GOOD
# 179: predict:[-0.104] real:[0] GOOD
# 180: predict:[-0.442] real:[0] GOOD
# 181: predict:[0.15] real:[0] GOOD
# 182: predict:[0.81] real:[1] GOOD
# 183: predict:[0.658] real:[1] GOOD
# 184: predict:[0.631] real:[1] GOOD
# 185: predict:[0.066] real:[0] GOOD
# 186: predict:[0.761] real:[1] GOOD
# 187: predict:[0.194] real:[0] GOOD
# 188: predict:[-0.166] real:[0] GOOD
# 189: predict:[0.754] real:[1] GOOD
# 190: predict:[0.475] real:[1] BAD
# 191: predict:[0.679] real:[1] GOOD
# 192: predict:[0.612] real:[1] GOOD
# 193: predict:[0.402] real:[0] GOOD
# 194: predict:[0.565] real:[1] GOOD
# 195: predict:[0.908] real:[1] GOOD
# 196: predict:[0.672] real:[1] GOOD
# 197: predict:[-0.232] real:[0] GOOD
# 198: predict:[-0.349] real:[0] GOOD
# 199: predict:[0.655] real:[1] GOOD
# 200: predict:[-0.285] real:[0] GOOD
# 201: predict:[0.705] real:[1] GOOD
# 202: predict:[0.198] real:[0] GOOD
# 203: predict:[0.642] real:[1] GOOD
# 204: predict:[0.422] real:[0] GOOD
# 205: predict:[-0.107] real:[0] GOOD
# 206: predict:[0.119] real:[0] GOOD
# 207: predict:[-0.255] real:[0] GOOD
# 208: predict:[-0.18] real:[0] GOOD
# 209: predict:[0.672] real:[1] GOOD
# 210: predict:[0.702] real:[1] GOOD
# 211: predict:[0.85] real:[1] GOOD
# 212: predict:[-0.418] real:[0] GOOD
# 213: predict:[-0.509] real:[0] GOOD
# 214: predict:[0.765] real:[1] GOOD
# 215: predict:[0.374] real:[0] GOOD
# 216: predict:[0.849] real:[1] GOOD
# 217: predict:[0.629] real:[1] GOOD
# 218: predict:[-0.8] real:[0] GOOD
# 219: predict:[0.518] real:[1] GOOD
# 220: predict:[0.022] real:[0] GOOD
# 221: predict:[0.005] real:[0] GOOD
# 222: predict:[0.077] real:[0] GOOD
# 223: predict:[0.604] real:[1] GOOD
# 224: predict:[0.714] real:[1] GOOD
# 225: predict:[-0.757] real:[0] GOOD
# 226: predict:[0.708] real:[1] GOOD
# 227: predict:[0.008] real:[0] GOOD
# 228: predict:[-0.273] real:[0] GOOD
# 229: predict:[-0.393] real:[0] GOOD
# 230: predict:[0.828] real:[1] GOOD
# 231: predict:[-0.215] real:[0] GOOD
# 232: predict:[0.747] real:[1] GOOD
# 233: predict:[0.082] real:[0] GOOD
# 234: predict:[0.701] real:[1] GOOD
# 235: predict:[0.674] real:[1] GOOD
# 236: predict:[0.491] real:[1] BAD
# 237: predict:[-0.175] real:[0] GOOD
# 238: predict:[0.713] real:[1] GOOD
# 239: predict:[0.323] real:[0] GOOD
# 240: predict:[0.636] real:[1] GOOD
# 241: predict:[0.75] real:[1] GOOD
# 242: predict:[0.745] real:[1] GOOD
# 243: predict:[-0.187] real:[0] GOOD
# 244: predict:[0.883] real:[1] GOOD
# 245: predict:[0.562] real:[1] GOOD
# 246: predict:[0.57] real:[1] GOOD
# 247: predict:[-0.301] real:[0] GOOD
# 248: predict:[0.138] real:[0] GOOD
# 249: predict:[-0.363] real:[0] GOOD
# 250: predict:[1.015] real:[1] GOOD
# 251: predict:[0.714] real:[1] GOOD
# 252: predict:[0.726] real:[1] GOOD
# 253: predict:[0.835] real:[1] GOOD
# 254: predict:[0.715] real:[1] GOOD
# 255: predict:[-0.024] real:[0] GOOD
# 256: predict:[-0.165] real:[0] GOOD
# 257: predict:[-0.051] real:[0] GOOD
# 258: predict:[0.885] real:[1] GOOD
# 259: predict:[0.05] real:[0] GOOD
# 260: predict:[-0.427] real:[0] GOOD
# 261: predict:[-0.229] real:[0] GOOD
# 262: predict:[0.512] real:[1] GOOD
# 263: predict:[0.57] real:[1] GOOD
# 264: predict:[-0.592] real:[0] GOOD
# 265: predict:[0.129] real:[0] GOOD
# 266: predict:[1.013] real:[1] GOOD
# 267: predict:[-0.365] real:[0] GOOD
# 268: predict:[0.937] real:[1] GOOD
# 269: predict:[-0.345] real:[0] GOOD
# 270: predict:[0.554] real:[1] GOOD
# 271: predict:[0.409] real:[0] GOOD
# 272: predict:[0.71] real:[1] GOOD
# 273: predict:[0.603] real:[1] GOOD
# 274: predict:[0.28] real:[0] GOOD
# 275: predict:[0.826] real:[1] GOOD
# 276: predict:[0.998] real:[1] GOOD
# 277: predict:[-0.584] real:[0] GOOD
# 278: predict:[0.552] real:[1] GOOD
# 279: predict:[0.852] real:[1] GOOD
# 280: predict:[0.673] real:[1] GOOD
# 281: predict:[-0.244] real:[0] GOOD
# 282: predict:[0.275] real:[0] GOOD
# 283: predict:[0.134] real:[0] GOOD
# 284: predict:[0.865] real:[1] GOOD
# 285: predict:[0.959] real:[1] GOOD
# 286: predict:[0.954] real:[1] GOOD
# 287: predict:[-0.098] real:[0] GOOD
# 288: predict:[0.466] real:[1] BAD
# 289: predict:[0.75] real:[1] GOOD
# 290: predict:[-0.243] real:[0] GOOD
# 291: predict:[-0.114] real:[0] GOOD
# 292: predict:[0.854] real:[1] GOOD
# 293: predict:[0.972] real:[1] GOOD
# 294: predict:[-0.127] real:[0] GOOD
# 295: predict:[0.791] real:[1] GOOD
# 296: predict:[0.265] real:[0] GOOD
# 297: predict:[0.76] real:[1] GOOD
# 298: predict:[0.747] real:[1] GOOD
# 299: predict:[-0.437] real:[0] GOOD
# 300: predict:[0.117] real:[0] GOOD
# 301: predict:[-0.14] real:[0] GOOD
# 302: predict:[0.767] real:[1] GOOD
# 303: predict:[0.268] real:[0] GOOD
# 304: predict:[0.3] real:[0] GOOD
# 305: predict:[0.707] real:[1] GOOD
# 306: predict:[0.764] real:[1] GOOD
# 307: predict:[-0.029] real:[0] GOOD
# 308: predict:[-0.256] real:[0] GOOD
# 309: predict:[0.433] real:[1] BAD
# 310: predict:[0.048] real:[0] GOOD
# 311: predict:[0.165] real:[0] GOOD
# 312: predict:[-0.536] real:[0] GOOD
# 313: predict:[-0.169] real:[0] GOOD
# 314: predict:[0.08] real:[0] GOOD
# 315: predict:[-0.125] real:[0] GOOD
# 316: predict:[0.009] real:[0] GOOD
# 317: predict:[0.444] real:[0] GOOD
# 318: predict:[-0.566] real:[0] GOOD
# 319: predict:[0.661] real:[1] GOOD
# 320: predict:[-0.006] real:[0] GOOD
# 321: predict:[-0.276] real:[0] GOOD
# 322: predict:[-0.322] real:[0] GOOD
# 323: predict:[-0.045] real:[0] GOOD
# 324: predict:[0.627] real:[1] GOOD
# 325: predict:[0.026] real:[0] GOOD
# 326: predict:[0.703] real:[1] GOOD
# 327: predict:[0.788] real:[1] GOOD
# 328: predict:[0.793] real:[1] GOOD
# 329: predict:[-0.077] real:[0] GOOD
# 330: predict:[0.771] real:[1] GOOD
# 331: predict:[0.567] real:[1] GOOD
# 332: predict:[0.731] real:[1] GOOD
# 333: predict:[0.617] real:[0] BAD
# 334: predict:[-0.18] real:[0] GOOD
# 335: predict:[0.557] real:[1] GOOD
# 336: predict:[0.008] real:[0] GOOD
# 337: predict:[0.415] real:[1] BAD
# 338: predict:[0.346] real:[0] GOOD
# 339: predict:[0.291] real:[0] GOOD
# 340: predict:[0.797] real:[1] GOOD
# 341: predict:[0.921] real:[1] GOOD
# 342: predict:[0.501] real:[0] BAD
# 343: predict:[0.053] real:[0] GOOD
# 344: predict:[0.604] real:[1] GOOD
# 345: predict:[0.806] real:[1] GOOD
# 346: predict:[0.568] real:[1] GOOD
# 347: predict:[0.767] real:[1] GOOD
# 348: predict:[0.748] real:[1] GOOD
# 349: predict:[1.015] real:[1] GOOD
# 350: predict:[0.196] real:[0] GOOD
# 351: predict:[-0.162] real:[0] GOOD
# 352: predict:[0.524] real:[1] GOOD
# 353: predict:[-0.195] real:[0] GOOD
# 354: predict:[-0.478] real:[0] GOOD
# 355: predict:[-0.028] real:[0] GOOD
# 356: predict:[0.753] real:[1] GOOD
# 357: predict:[0.402] real:[0] GOOD
# 358: predict:[-0.213] real:[0] GOOD
# 359: predict:[0.865] real:[1] GOOD
# 360: predict:[0.092] real:[0] GOOD
# 361: predict:[0.834] real:[1] GOOD
# 362: predict:[0.707] real:[1] GOOD
# 363: predict:[-0.297] real:[0] GOOD
# 364: predict:[0.127] real:[0] GOOD
# 365: predict:[-0.199] real:[0] GOOD
# 366: predict:[0.743] real:[1] GOOD
# 367: predict:[0.731] real:[1] GOOD
# 368: predict:[0.311] real:[0] GOOD
# 369: predict:[0.336] real:[0] GOOD
# 370: predict:[0.758] real:[1] GOOD
# 371: predict:[0.899] real:[1] GOOD
# 372: predict:[0.693] real:[1] GOOD
# 373: predict:[-0.257] real:[0] GOOD
# 374: predict:[0.48] real:[0] GOOD
# 375: predict:[0.026] real:[0] GOOD
# 376: predict:[0.994] real:[1] GOOD
# 377: predict:[0.589] real:[1] GOOD
# 378: predict:[0.541] real:[1] GOOD
# 379: predict:[-0.322] real:[0] GOOD
# 380: predict:[-0.038] real:[0] GOOD
# 381: predict:[0.878] real:[1] GOOD
# 382: predict:[-0.204] real:[0] GOOD
# 383: predict:[0.552] real:[0] BAD
# 384: predict:[0.547] real:[0] BAD
# 385: predict:[0.931] real:[1] GOOD
# 386: predict:[0.004] real:[0] GOOD
# 387: predict:[0.224] real:[0] GOOD
# 388: predict:[0.49] real:[1] BAD
# 389: predict:[-1.082] real:[0] GOOD
# 390: predict:[-0.249] real:[0] GOOD
# 391: predict:[0.303] real:[0] GOOD
# 392: predict:[0.656] real:[1] GOOD
# 393: predict:[0.668] real:[1] GOOD
# 394: predict:[-0.617] real:[0] GOOD
# 395: predict:[-0.036] real:[0] GOOD
# 396: predict:[0.009] real:[0] GOOD
# 397: predict:[0.759] real:[1] GOOD
# 398: predict:[-0.024] real:[0] GOOD
# 399: predict:[-0.663] real:[0] GOOD
# 400: predict:[0.471] real:[1] BAD
# 401: predict:[0.523] real:[0] BAD
# 402: predict:[0.539] real:[0] BAD
# 403: predict:[-0.486] real:[0] GOOD
# 404: predict:[-0.281] real:[0] GOOD
# 405: predict:[0.845] real:[1] GOOD
# 406: predict:[-0.035] real:[0] GOOD
# 407: predict:[0.859] real:[1] GOOD
# 408: predict:[0.456] real:[1] BAD
# 409: predict:[0.607] real:[1] GOOD
# 410: predict:[0.126] real:[0] GOOD
# 411: predict:[-0.341] real:[0] GOOD
# 412: predict:[0.517] real:[1] GOOD
# 413: predict:[0.849] real:[1] GOOD
# 414: predict:[0.79] real:[1] GOOD
# 415: predict:[-0.118] real:[0] GOOD
# 416: predict:[0.645] real:[1] GOOD
# 417: predict:[0.943] real:[1] GOOD
# 418: predict:[0.672] real:[1] GOOD
# 419: predict:[-0.298] real:[0] GOOD
# 420: predict:[0.221] real:[0] GOOD
# 421: predict:[0.737] real:[1] GOOD
# 422: predict:[0.668] real:[1] GOOD
# 423: predict:[-0.188] real:[0] GOOD
# 424: predict:[-0.001] real:[0] GOOD
# 425: predict:[0.686] real:[1] GOOD
# 426: predict:[0.132] real:[0] GOOD
# 427: predict:[0.513] real:[0] BAD
# 428: predict:[0.869] real:[1] GOOD
# 429: predict:[0.798] real:[1] GOOD
# 430: predict:[0.65] real:[0] BAD
# 431: predict:[-0.721] real:[0] GOOD
# 432: predict:[-0.332] real:[0] GOOD
# 433: predict:[0.61] real:[1] GOOD
# 434: predict:[0.928] real:[1] GOOD
# 435: predict:[-0.24] real:[0] GOOD
# 436: predict:[0.183] real:[0] GOOD
# 437: predict:[0.42] real:[0] GOOD
# 438: predict:[0.875] real:[1] GOOD
# 439: predict:[-0.082] real:[0] GOOD
# 440: predict:[-0.59] real:[0] GOOD
# 441: predict:[0.123] real:[0] GOOD
# 442: predict:[0.76] real:[1] GOOD
# 443: predict:[-0.475] real:[0] GOOD
# 444: predict:[0.527] real:[0] BAD
# 445: predict:[0.378] real:[0] GOOD
# 446: predict:[0.104] real:[0] GOOD
# 447: predict:[0.469] real:[0] GOOD
# 448: predict:[0.57] real:[1] GOOD
# 449: predict:[-0.242] real:[0] GOOD
# 450: predict:[0.683] real:[1] GOOD
# 451: predict:[0.937] real:[1] GOOD
# 452: predict:[0.431] real:[0] GOOD
# 453: predict:[0.848] real:[1] GOOD
# 454: predict:[0.899] real:[1] GOOD
# 455: predict:[0.418] real:[1] BAD
# 456: predict:[0.608] real:[1] GOOD
# 457: predict:[-0.149] real:[0] GOOD
# 458: predict:[0.761] real:[1] GOOD
# 459: predict:[0.689] real:[1] GOOD
# 460: predict:[0.518] real:[1] GOOD
# 461: predict:[0.677] real:[1] GOOD
# 462: predict:[-0.263] real:[0] GOOD
# 463: predict:[0.501] real:[1] GOOD
# 464: predict:[-0.506] real:[0] GOOD
# 465: predict:[0.72] real:[1] GOOD
# 466: predict:[0.271] real:[0] GOOD
# 467: predict:[0.612] real:[1] GOOD
# 468: predict:[-0.32] real:[0] GOOD
# 469: predict:[-0.438] real:[0] GOOD
# 470: predict:[0.359] real:[0] GOOD
# 471: predict:[-0.189] real:[0] GOOD
# 472: predict:[0.698] real:[1] GOOD
# 473: predict:[0.688] real:[1] GOOD
# 474: predict:[-0.242] real:[0] GOOD
# 475: predict:[0.546] real:[1] GOOD
# 476: predict:[0.833] real:[1] GOOD
# 477: predict:[0.878] real:[1] GOOD
# 478: predict:[-0.156] real:[0] GOOD
# 479: predict:[1.025] real:[1] GOOD
# 480: predict:[-0.457] real:[0] GOOD
# 481: predict:[-0.008] real:[0] GOOD
# 482: predict:[0.329] real:[0] GOOD
# 483: predict:[0.614] real:[1] GOOD
# 484: predict:[0.057] real:[0] GOOD
# 485: predict:[-0.081] real:[0] GOOD
# 486: predict:[-0.013] real:[0] GOOD
# 487: predict:[-0.079] real:[0] GOOD
# 488: predict:[-0.158] real:[0] GOOD
# 489: predict:[-0.036] real:[0] GOOD
# 490: predict:[-0.066] real:[0] GOOD
# 491: predict:[0.716] real:[1] GOOD
# 492: predict:[-0.047] real:[0] GOOD
# 493: predict:[0.203] real:[0] GOOD
# 494: predict:[-0.363] real:[0] GOOD
# 495: predict:[-0.048] real:[0] GOOD
# 496: predict:[-0.054] real:[0] GOOD
# 497: predict:[0.574] real:[0] BAD
# 498: predict:[0.554] real:[1] GOOD
# 499: predict:[0.747] real:[1] GOOD

# %%
# JUST LIKE THAT
print("Summary:")
print(f"{good}/500 were correct ({good/500*100}%)")
print(f"{bad}/500 were incorrect ({bad/500*100}%)")
# Out:
# Summary:
# 470/500 were correct (94.0%)
# 30/500 were incorrect (6.0%)
